# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadHammad02/Tensorflow-Deep-Learning-Machine-Learning/blob/main/Tensorflow_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0,0.0,1.0,2.0,3.0,4.0], dtype=float)
xy = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0], dtype=float)

# %%
model.fit(xs,xy, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 624ms/step - loss: 4.1579
# Epoch 2/500
# 1/1 [==============================] - 0s 11ms/step - loss: 3.4385
# Epoch 3/500
# 1/1 [==============================] - 0s 12ms/step - loss: 2.8691
# Epoch 4/500
# 1/1 [==============================] - 0s 11ms/step - loss: 2.4178
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 2.0594
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7742
# Epoch 7/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.5467
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3645
# Epoch 9/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2182
# Epoch 10/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1001
# Epoch 11/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0043
# Epoch 12/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.9261
# ...

# %%
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 110ms/step
# [[18.984674]]
